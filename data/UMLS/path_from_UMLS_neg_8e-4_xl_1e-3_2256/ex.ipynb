# %%
import pandas as pd

# %%
ex = pd.read_parquet("UMLS-train-subq_sampled_max5_w_path.parquet")

# %%
ex
# Out:
#       query_type                                              query  \
# 0            2in  What are the entities that interact with hazar...
# 1             2p  What are the effects of issues related to occu...
# 2            pni  What are the entities that are not part of con...
# 3             3p  What are the entities associated with the enti...
# 4             2p  What are the things indicated by the concepts ...
# ...          ...                                                ...
# 22804        inp  What are the superclasses of hormones that are...
# 22805        pin  What population groups are associated with cau...
# 22806         3i  What family groups have both a direct and indi...
# 22807         2p  What are the complications of the pathologic f...
# 22808         3p  What are the conceptual parts of issues relate...
#
#                                                 q_entity  \
# 0      [hazardous_or_poisonous_substance, laboratory_...
# ...
